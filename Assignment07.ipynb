# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('compensation data.csv')
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
print(df.head())
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288

# %%
headers = df.columns.tolist()
print(headers)
# Out:
# ['experience_coding', 'python_user', 'r_user', 'sql_user', 'most_used', 'compensation']

# %%
survey = df.iloc[1:].reset_index(drop=True)
print(survey)
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                   12.3         True    True      True  Scikit-learn
# 1                    2.2         True   False     False           NaN
# 2                    2.7        False   False      True           NaN
# 3                    1.2         True   False     False  Scikit-learn
# 4                    1.0         True   False     False       PyTorch
# ...                  ...          ...     ...       ...           ...
# 25967                1.9         True   False      True  Scikit-learn
# 25968                1.4         True   False     False       PyTorch
# 25969                0.0        False   False     False           NaN
# 25970                9.4         True   False      True  Scikit-learn
# 25971                0.0        False   False     False           NaN
#
#        compensation
# 0            236889
# 1             74321
# 2             62593
# 3             36288
# ...

# %%
for index, row in survey.iterrows():
    print(type(row[5]))
# Out:
# C:\Users\n tech\AppData\Local\Temp\ipykernel_1164\2670408642.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(type(row[5]))
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
for index, row in survey.iterrows():
    first_element = row[0]
    second_element = row[1]
    third_element = row[2]
    fourth_element = row[3]
    fifth_element = row[4]
    sixth_element = row[5]
    survey.at[index, survey.columns[0]] = float(first_element)

    if second_element == "TRUE":
        survey.at[index, survey.columns[1]] = True
    else:
        survey.at[index, survey.columns[1]] = False

    if third_element == "TRUE":
        survey.at[index, survey.columns[2]] = True
    else:
        survey.at[index, survey.columns[2]] = False

    if fourth_element == "TRUE":
        survey.at[index, survey.columns[3]] = True
    else:
        survey.at[index, survey.columns[3]] = False

    if fifth_element == "None":
        survey.at[index, survey.columns[4]] = None
    else:
        survey.at[index, survey.columns[4]] = fifth_element

    survey.at[index, survey.columns[5]] = float(sixth_element)

print(survey)
# Out:
# C:\Users\n tech\AppData\Local\Temp\ipykernel_1164\2312813710.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   first_element = row[0]
# C:\Users\n tech\AppData\Local\Temp\ipykernel_1164\2312813710.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   second_element = row[1]
# C:\Users\n tech\AppData\Local\Temp\ipykernel_1164\2312813710.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   third_element = row[2]
# ...

# %%
print(survey[:3])
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0               12.3        False   False     False  Scikit-learn
# 1                2.2        False   False     False           NaN
# 2                2.7        False   False     False           NaN
#
#    compensation
# 0        236889
# 1         74321
# 2         62593

# %%
for index in range(len(survey)):
    print(survey.iloc[index, 5])
# Out:
# 236889
# 74321
# 62593
# 36288
# 61302
# 68984
# 18858
# 55418
# 614
# 70564
# 55525
# 61005
# 2846
# 21
# 14699
# 2110
# 620
# 73527
# 6992
# 22311
# 1377
# 69174
# 117636
# 65937
# 27856
# 903
# 50501
# 482
# 70407
# 8690
# 114648
# 73454
# 8075
# 59151
# 70112
# 70183
# 64502
# 2521
# 63616
# 59849
# 31516
# 18582
# 4187
# 64405
# 114807
# 632
# 61157
# 1194
# 28955
# 56553
# 75177
# 28009
# 67074
# 50059
# 7624
# 74321
# 671
# 837
# 2011
# 62937
# 685
# 41615
# 52572
# 51856
# 411
# 152
# 8181
# 2708
# 55041
# 68412
# 6141
# 3979
# 3760
# 57465
# 3864
# 488487
# 24393
# 68624
# 70796
# 236889
# 57861
# 21055
# 59167
# 55882
# 73802
# 21206
# 79803
# 73043
# 268191
# 14298
# 68805
# 56003
# 73664
# 434
# 52109
# 10284
# 43906
# 67971
# 58465
# 64488
# 7709
# 1957
# 4131
# 26022
# 29926
# 62593
# 109543
# 107644
# 1047
# 59909
# 68344
# 54427
# 70930
# 50835
# 14151
# 11681
# 71808
# 70991
# 31626
# 52416
# 288146
# 65143
# 34866
# 186
# 60065
# 40336
# 115654
# 431
# 59814
# ...

# %%
python_user = survey.iloc[:, 1].sum()  
r_user = survey.iloc[:, 2].sum()    
sql_user = survey.iloc[:, 3].sum()    

print("Python users:", python_user)
print("R users:", r_user)
print("SQL users:", sql_user)
# Out:
# Python users: 0
# R users: 0
# SQL users: 0

# %%
for index, row in survey.iterrows():
    exp = row[0]  
    comp = row[-1]  
    print(exp)
# Out:
# C:\Users\n tech\AppData\Local\Temp\ipykernel_1164\713644845.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   exp = row[0]
# C:\Users\n tech\AppData\Local\Temp\ipykernel_1164\713644845.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   comp = row[-1]
# 12.3
# 2.2
# 2.7
# 1.2
# 1.0
# 1.8
# 6.1
# 4.5
# 1.1
# 2.7
# 0.93
# 0.32
# 9.9
# 0.78
# 13.5
# 26.5
# 1.5
# 3.4
# 0.6
# 0.95
# 4.6
# 2.8
# 28.2
# 1.4
# 4.8
# 0.37
# 4.5
# 4.4
# 0.69
# 1.5
# 9.6
# 0.31
# 3.5
# 1.0
# 0.2
# 0.39
# 5.0
# 4.0
# 0.47
# 8.1
# 1.8
# 17.1
# 1.4
# 1.3
# 3.1
# 0.26
# 2.1
# 4.4
# 5.2
# 0.7
# 0.69
# 1.3
# 1.5
# 2.2
# 6.3
# 2.9
# 1.2
# 1.5
# ...

# %%
experience = survey.iloc[:, 0].tolist()  
compensation = survey.iloc[:, -1].tolist() 
print(experience)
print(compensation)
# Out:
# [12.3, 2.2, 2.7, 1.2, 1.0, 1.8, 6.1, 4.5, 1.1, 2.7, 0.93, 0.32, 9.9, 0.78, 13.5, 26.5, 1.5, 3.4, 0.6, 0.95, 4.6, 2.8, 28.2, 1.4, 4.8, 0.37, 4.5, 4.4, 0.69, 1.5, 9.6, 0.31, 3.5, 1.0, 0.2, 0.39, 5.0, 4.0, 0.47, 8.1, 1.8, 17.1, 1.4, 1.3, 3.1, 0.26, 2.1, 4.4, 5.2, 0.7, 0.69, 1.3, 1.5, 2.2, 6.3, 2.9, 1.2, 1.5, 1.8, 0.91, 4.5, 1.6, 0.27, 2.6, 1.7, 0.74, 2.7, 0.99, 24.8, 0.32, 3.5, 5.7, 22.0, 9.9, 3.9, 20.5, 0.81, 9.8, 1.5, 12.3, 6.6, 2.1, 2.5, 0.0, 1.7, 5.3, 1.4, 1.5, 28.2, 0.97, 1.1, 7.0, 1.0, 0.71, 9.3, 1.7, 20.5, 0.75, 0.98, 0.8, 1.3, 0.36, 1.2, 8.6, 18.4, 2.7, 24.3, 0.94, 1.4, 3.3, 0.93, 2.3, 0.59, 1.2, 8.5, 3.3, 21.1, 1.2, 12.2, 3.8, 4.3, 13.1, 24.3, 1.6, 2.9, 9.4, 7.7, 0.3, 9.0, 4.2, 1.9, 8.3, 0.21, 18.8, 9.3, 1.8, 2.8, 2.4, 15.3, 3.9, 0.3, 0.8, 0.79, 11.1, 0.24, 19.7, 8.5, 0.26, 0.75, 24.4, 6.8, 4.4, 3.2, 0.84, 16.0, 4.9, 8.3, 6.6, 4.0, 23.9, 27.0, 0.91, 2.2, 13.9, 3.4, 1.4, 6.6, 2.6, 8.5, 28.2, 2.7, 8.6, 2.9, 2.6, 7.5, 1.3, 16.2, 2.7, 1.8, 7.1, 1.9, 0.41, 2.3, 11.8, 4.0, 5.4, 3.8, 
# ...

# %%
print(experience[:10])
# Out:
# [12.3, 2.2, 2.7, 1.2, 1.0, 1.8, 6.1, 4.5, 1.1, 2.7]

# %%
print(compensation)
# Out:
# [236889, 74321, 62593, 36288, 61302, 68984, 18858, 55418, 614, 70564, 55525, 61005, 2846, 21, 14699, 2110, 620, 73527, 6992, 22311, 1377, 69174, 117636, 65937, 27856, 903, 50501, 482, 70407, 8690, 114648, 73454, 8075, 59151, 70112, 70183, 64502, 2521, 63616, 59849, 31516, 18582, 4187, 64405, 114807, 632, 61157, 1194, 28955, 56553, 75177, 28009, 67074, 50059, 7624, 74321, 671, 837, 2011, 62937, 685, 41615, 52572, 51856, 411, 152, 8181, 2708, 55041, 68412, 6141, 3979, 3760, 57465, 3864, 488487, 24393, 68624, 70796, 236889, 57861, 21055, 59167, 55882, 73802, 21206, 79803, 73043, 268191, 14298, 68805, 56003, 73664, 434, 52109, 10284, 43906, 67971, 58465, 64488, 7709, 1957, 4131, 26022, 29926, 62593, 109543, 107644, 1047, 59909, 68344, 54427, 70930, 50835, 14151, 11681, 71808, 70991, 31626, 52416, 288146, 65143, 34866, 186, 60065, 40336, 115654, 431, 59814, 45413, 4196, 55751, 61912, 49478, 29139, 67272, 70264, 264, 14853, 55482, 26, 250, 66025, 55906, 63754, 86855, 63242, 70448, 68964, 1
# ...

# %%
print(min(experience))   
print(max(experience))
# Out:
# 0.0
# 30.0

# %%
average_experience = survey.iloc[:, 0].mean()
print(average_experience)
# Out:
# 5.2972008316648695

# %%
print(min(compensation))
print(max(compensation))
sum(compensation)/len(compensation)
# Out:
# 0
# 1492951
# 53250.08270445095

# %%
def categorize_years(years):
    if years < 5:
        return "< 5 Years"
    elif years < 10:
        return "5-10 Years"
    elif years < 15:
        return "10-15 Years"
    elif years < 20:
        return "15-20 Years"
    elif years < 25:
        return "20-25 Years"
    else:
        return "25+ Years"

survey['category'] = survey.iloc[:, 0].apply(categorize_years)

print(survey)
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                   12.3        False   False     False  Scikit-learn
# 1                    2.2        False   False     False           NaN
# 2                    2.7        False   False     False           NaN
# 3                    1.2        False   False     False  Scikit-learn
# 4                    1.0        False   False     False       PyTorch
# ...                  ...          ...     ...       ...           ...
# 25967                1.9        False   False     False  Scikit-learn
# 25968                1.4        False   False     False       PyTorch
# 25969                0.0        False   False     False           NaN
# 25970                9.4        False   False     False  Scikit-learn
# 25971                0.0        False   False     False           NaN
#
#        compensation     category
# 0            236889  10-15 Years
# 1             74321    < 5 Years
# ...

# %%
lessthan5 = []
fiveto10 = []
tento15 = []
fifteento20 = []
twentyto25 = []
moretha25 = []

lessthan5 = survey[survey['category'] == "< 5 Years"].iloc[:, -2].tolist()
fiveto10 = survey[survey['category'] == "5-10 Years"].iloc[:, -2].tolist()
tento15 = survey[survey['category'] == "10-15 Years"].iloc[:, -2].tolist()
fifteento20 = survey[survey['category'] == "15-20 Years"].iloc[:, -2].tolist()
twentyto25 = survey[survey['category'] == "20-25 Years"].iloc[:, -2].tolist()
moretha25 = survey[survey['category'] == "25+ Years"].iloc[:, -2].tolist()
print("Less than 5 years:", lessthan5)
print("5-10 years:", fiveto10)
print("10-15 years:", tento15)
print("15-20 years:", fifteento20)
print("20-25 years:", twentyto25)
print("More than 25 years:", moretha25)
# Out:
# Less than 5 years: [74321, 62593, 36288, 61302, 68984, 55418, 614, 70564, 55525, 61005, 21, 620, 73527, 6992, 22311, 1377, 69174, 65937, 27856, 903, 50501, 482, 70407, 8690, 73454, 8075, 59151, 70112, 70183, 2521, 63616, 31516, 4187, 64405, 114807, 632, 61157, 1194, 56553, 75177, 28009, 67074, 50059, 74321, 671, 837, 2011, 62937, 685, 41615, 52572, 51856, 411, 152, 8181, 2708, 68412, 6141, 3864, 24393, 70796, 21055, 59167, 55882, 73802, 79803, 73043, 14298, 68805, 73664, 434, 10284, 67971, 58465, 64488, 7709, 1957, 4131, 62593, 107644, 1047, 59909, 68344, 54427, 70930, 50835, 11681, 70991, 52416, 288146, 186, 60065, 431, 45413, 4196, 61912, 67272, 70264, 264, 55482, 26, 250, 66025, 63754, 70448, 68964, 58574, 330, 64478, 62142, 60873, 27748, 239, 332, 51428, 50783, 226, 8015, 450, 348, 59456, 62821, 59666, 57673, 29472, 5119, 282, 106203, 74289, 74445, 67736, 785, 28073, 20390, 4791, 73319, 44491, 74799, 57207, 14370, 57816, 62513, 59687, 67959, 1337, 72317, 66163, 11165, 388, 12925,
# ...

# %%
categories_dict = {
    "< 5 Years": lessthan5,
    "5-10 Years": fiveto10,
    "10-15 Years": tento15,
    "15-20 Years": fifteento20,
    "20-25 Years": twentyto25,
    "25+ Years": moretha25
}

for category, values in categories_dict.items():
    if values: 
        print(f"Average for {category}: {sum(values) / len(values)}")
    else:
        print(f"Average for {category}: No data")
# Out:
# Average for < 5 Years: 45047.87484669119
# Average for 5-10 Years: 59292.3041692988
# Average for 10-15 Years: 80226.75581395348
# Average for 15-20 Years: 75101.82694106642
# Average for 20-25 Years: 103159.80432432433
# Average for 25+ Years: 90444.98512221042

# %%
survey.columns = survey.columns.append(pd.Index(["categories"]))
print(survey.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 survey.columns = survey.columns.append(pd.Index(["categories"]))
#       2 print(survey.columns)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# ...
